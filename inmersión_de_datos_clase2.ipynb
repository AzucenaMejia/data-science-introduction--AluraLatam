# %% [markdown]
# <a href="https://colab.research.google.com/github/AzucenaMejia/data-science-introduction--AluraLatam/blob/main/inmersi%C3%B3n_de_datos_clase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount("/content/driver")
# Out:
# Mounted at /content/driver

# %%
import pandas as pd
inmuebles = pd.read_csv('/content/driver/MyDrive/curso de Alura Latam/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
columnas = {'Baños':'Baños','Área':'Area'}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                Descripcion  Habitaciones  \
# 9307  Apartamento               Apartamento en venta en Suba             2
# 1765  Apartamento     Apartamento en venta en Barrios Unidos             3
# 330         Local                Local en venta en Chapinero             2
# 7776         Casa                   Casa en venta en Kennedy             8
# 4728  Apartamento     Apartamento en venta en Barrios Unidos             3
# 50    Apartamento           Apartamento en venta en Cedritos             2
# 3913  Apartamento            Apartamento en venta en Usaquén             2
# 1260  Apartamento            Apartamento en venta en Usaquén             3
# 3831         Casa        Casa en venta en Zona Noroccidental             3
# 5843  Apartamento  Apartamento en venta en Chapinero Central             1
#
#       Baños  Area              Barrio                                 UPZ  \
# ...

# %%
inmuebles.sample(8)
# Out:
#              Tipo                           Descripcion  Habitaciones  Baños  \
# 1496  Apartamento       Apartamento en venta en Usaquén             3      2
# 7389  Apartamento       Apartamento en venta en Usaquén             2      2
# 8754  Apartamento  Apartamento en venta en San Patricio             2      3
# 7916         Casa              Casa en venta en Usaquén             3      3
# 8946         Casa             Casa en venta en Engativa             2      2
# 6032  Apartamento       Apartamento en venta en Kennedy             3      1
# 2300  Apartamento      Apartamento en venta en Cedritos             4      2
# 2940  Apartamento          Apartamento en venta en Bosa             3      1
#
#       Area        Barrio                                    UPZ          Valor
# 1496    87       Usaquén                                Usaquén  $ 420.000.000
# 7389    51       Usaquén                                Usaquén  $ 205.000.000
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Baños         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.Valor[0]
# Out:
# '$ 360.000.000'

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %%
inmuebles.Valor[0]+inmuebles.Valor[1]
# Out:
# '$ 360.000.000$ 670.000.000'

# %%
inmuebles.Valor[0]+inmuebles.Valor[1]+inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000$ 670.000.000$ 360.000.000
# 1      $ 360.000.000$ 670.000.000$ 670.000.000
# 2    $ 360.000.000$ 670.000.000$ 1.120.000.000
# 3      $ 360.000.000$ 670.000.000$ 890.000.000
# 4      $ 360.000.000$ 670.000.000$ 970.000.000
# Name: Valor, dtype: object

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
inmuebles.Valor.str.split()
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %%
type(inmuebles.Valor.str.split())
# Out:
# pandas.core.series.Series

# %%
inmuebles.Valor.str.split(expand=True)
# Out:
#       0              1
# 0     $    360.000.000
# 1     $    670.000.000
# 2     $  1.120.000.000
# 3     $    890.000.000
# 4     $    970.000.000
# ...  ..            ...
# 9515  $    290.000.000
# 9516  $    670.000.000
# 9517  $    900.000.000
# 9518  $    335.000.000
# 9519  $    144.990.000
#
# [9520 rows x 2 columns]

# %%
valor=inmuebles.Valor.str.split(expand=True)
inmuebles["Moneda"] = valor[0]
inmuebles["Precio"] = valor[1]
inmuebles.sample()
# Out:
#              Tipo                            Descripcion  Habitaciones  Baños  \
# 8387  Apartamento  Apartamento en venta en Santa Barbara             4      3
#
#       Area         Barrio                                    UPZ  \
# 8387   160  Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
#
#                 Valor Moneda         Precio
# 8387  $ 1.200.000.000      $  1.200.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Baños         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 669.5+ KB

# %%
inmuebles["Precio"]
# Out:
# 0         360.000.000
# 1         670.000.000
# 2       1.120.000.000
# 3         890.000.000
# 4         970.000.000
#             ...
# 9515      290.000.000
# 9516      670.000.000
# 9517      900.000.000
# 9518      335.000.000
# 9519      144.990.000
# Name: Precio, Length: 9520, dtype: object

# %%
inmuebles['Precio']= inmuebles['Precio'].str.replace('.','',regex=True)

# %%
inmuebles[["Precio","Barrio"]]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Baños         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles["Precio_Millon"] = inmuebles.Precio.astype("float")/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Baños          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Baños           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
pd.set_option("display.precision",2)
pd.set_option("display.float_format", lambda x: "%.2f" % x)
inmuebles.describe()
# Out:
#        Habitaciones   Baños      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
inmuebles.loc[inmuebles.Habitaciones==110]
# Out:
#      Tipo                Descripcion  Habitaciones  Baños  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[inmuebles.Area==2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Baños  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %%
inmuebles["Precio_Millon"].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
inmuebles["Precio_Millon"].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
inmuebles["Precio_Millon"].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt,plt.figure(figsize=(10,8))
grafica=sns.histplot(data=inmuebles, x="Precio_Millon" ,kde=True )
grafica.set_title("Distribucion de Valores de los inmuebles de Bogotá")
plt.xlim((50,2000))
plt.show()

# %% [markdown]
# # Nueva sección

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt,plt.figure(figsize=(10,6))
grafica=sns.histplot(data=inmuebles, x="Precio_Millon", hue="Tipo")
grafica.set_title("Distribucion de Valores de los inmuebles de Bogotá")
plt.xlim((50,1000))
plt.xlim((0,20))
plt.savefig('/content/driver/MyDrive/curso de Alura Latam/descarga.png',format='png')
plt.show()
